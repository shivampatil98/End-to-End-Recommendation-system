# %%
import numpy as np
import pandas as pd

# %%
books = pd.read_csv('Books.csv', sep=",", on_bad_lines='skip', encoding='latin-1')
# Out:
# C:\Users\shiva\AppData\Local\Temp\ipykernel_64628\3864644893.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   books = pd.read_csv('Books.csv', sep=",", on_bad_lines='skip', encoding='latin-1')

# %%
books.head()
# Out:
#         ISBN                                         Book-Title  \
# 0  195153448                                Classical Mythology
# 1    2005018                                       Clara Callan
# 2   60973129                               Decision in Normandy
# 3  374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...
#
#                                          Image-URL-L
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...

# %%
books.iloc[10]['Image-URL-L']
# Out:
# 'http://images.amazon.com/images/P/0771074670.01.LZZZZZZZ.jpg'

# %%
books.shape
# Out:
# (271360, 8)

# %%
books.columns
# Out:
# Index(['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher',
#        'Image-URL-S', 'Image-URL-M', 'Image-URL-L'],
#       dtype='object')

# %%
books = books[['ISBN','Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher','Image-URL-L']]

# %%
books.head()
# Out:
#         ISBN                                         Book-Title  \
# 0  195153448                                Classical Mythology
# 1    2005018                                       Clara Callan
# 2   60973129                               Decision in Normandy
# 3  374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-L
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...

# %%
# Lets rename columns name
books.rename(columns={"Book-Title":'title',
                      'Book-Author':'author',
                     "Year-Of-Publication":'year',
                     "Publisher":"publisher",
                     "Image-URL-L":"image_url"},inplace=True)

# %%
books.head()
# Out:
#         ISBN                                              title  \
# 0  195153448                                Classical Mythology
# 1    2005018                                       Clara Callan
# 2   60973129                               Decision in Normandy
# 3  374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  393045218                             The Mummies of Urumchi
#
#                  author  year                   publisher  \
# 0    Mark P. O. Morford  2002     Oxford University Press
# 1  Richard Bruce Wright  2001       HarperFlamingo Canada
# 2          Carlo D'Este  1991             HarperPerennial
# 3      Gina Bari Kolata  1999        Farrar Straus Giroux
# 4       E. J. W. Barber  1999  W. W. Norton &amp; Company
#
#                                            image_url
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...

# %%
# Now load the second dataframe

users = pd.read_csv('Users.csv', sep=",", on_bad_lines='skip', encoding='latin-1')

# %%
users.head()
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
users.shape
# Out:
# (278858, 3)

# %%
# Lets rename columns name
users.rename(columns={"User-ID":'user_id',
                      'Location':'location',
                     "Age":'age'},inplace=True)

# %%
# Now load the third dataframe

ratings = pd.read_csv('Ratings.csv', sep=",", on_bad_lines='skip', encoding='latin-1')

# %%
ratings.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
ratings.shape
# Out:
# (1149780, 3)

# %%
# Lets remane some wierd columns name
ratings.rename(columns={"User-ID":'user_id',
                      'Book-Rating':'rating'},inplace=True)

ratings.head()
# Out:
#    user_id        ISBN  rating
# 0   276725  034545104X       0
# 1   276726  0155061224       5
# 2   276727  0446520802       0
# 3   276729  052165615X       3
# 4   276729  0521795028       6

# %%
print(books.shape, users.shape, ratings.shape, sep='\n')
# Out:
# (271360, 6)
# (278858, 3)
# (1149780, 3)

# %%
ratings['user_id'].value_counts()
# Out:
# user_id
# 11676     13602
# 198711     7550
# 153662     6109
# 98391      5891
# 35859      5850
#           ...
# 116180        1
# 116166        1
# 116154        1
# 116137        1
# 276723        1
# Name: count, Length: 105283, dtype: int64

# %%
# Lets store users who had at least rated more than 200 books
x = ratings['user_id'].value_counts() > 200

# %%
x
# Out:
# user_id
# 11676      True
# 198711     True
# 153662     True
# 98391      True
# 35859      True
#           ...
# 116180    False
# 116166    False
# 116154    False
# 116137    False
# 276723    False
# Name: count, Length: 105283, dtype: bool

# %%
x[x].shape
# Out:
# (899,)

# %%
y=x[x].index
y
# Out:
# Index([ 11676, 198711, 153662,  98391,  35859, 212898, 278418,  76352, 110973,
#        235105,
#        ...
#        260183,  73681,  44296, 155916,   9856, 274808,  28634,  59727, 268622,
#        188951],
#       dtype='int64', name='user_id', length=899)

# %%
ratings = ratings[ratings['user_id'].isin(y)]

# %%
ratings.head()
# Out:
#       user_id        ISBN  rating
# 1456   277427  002542730X      10
# 1457   277427  0026217457       0
# 1458   277427  003008685X       8
# 1459   277427  0030615321       0
# 1460   277427  0060002050       0

# %%
# Now join ratings with books

ratings_with_books = ratings.merge(books, on='ISBN')

ratings_with_books.head()
# Out:
#    user_id        ISBN  rating  \
# 0   277427  002542730X      10
# 1   277427  003008685X       8
# 2   277427  006092988X       0
# 3   277427  006440188X       0
# 4   277427  014029628X       0
#
#                                                title                   author  \
# 0  Politically Correct Bedtime Stories: Modern Ta...        James Finn Garner
# 1                                           Pioneers    James Fenimore Cooper
# 2                           A Tree Grows in Brooklyn              Betty Smith
# 3                                  The Secret Garden  Frances Hodgson Burnett
# 4                              Girl in Hyacinth Blue           Susan Vreeland
#
#    year                  publisher  \
# 0  1994  John Wiley &amp; Sons Inc
# 1  1974           Thomson Learning
# 2  1998                  Perennial
# 3  1998               HarperTrophy
# 4  2000              Penguin Books
#
#                                            image_url
# 0  http://images.amazon.com/images/P/002542730X.0...
# 1  http://images.amazon.com/images/P/003008685X.0...
# 2  http://images.amazon.com/images/P/006092988X.0...
# 3  http://images.amazon.com/images/P/006440188X.0...
# 4  http://images.amazon.com/images/P/014029628X.0...

# %%
number_rating = ratings_with_books.groupby('title')['rating'].count().reset_index()

# %%
number_rating.head()
# Out:
#                                                title  rating
# 0   Earth Prayers From around the World: 365 Pray...       3
# 1   Final Fantasy Anthology: Official Strategy Gu...       3
# 2   Flight of Fancy: American Heiresses (Zebra Ba...       1
# 3   Little Comic Shop of Horrors (Give Yourself G...       4
# 4                                       Mystery Mile       1

# %%
number_rating.rename(columns={'rating':'num_of_rating'},inplace=True)

# %%
number_rating.head()
# Out:
#                                                title  num_of_rating
# 0   Earth Prayers From around the World: 365 Pray...              3
# 1   Final Fantasy Anthology: Official Strategy Gu...              3
# 2   Flight of Fancy: American Heiresses (Zebra Ba...              1
# 3   Little Comic Shop of Horrors (Give Yourself G...              4
# 4                                       Mystery Mile              1

# %%
final_rating = ratings_with_books.merge(number_rating, on='title')

# %%
final_rating.head()
# Out:
#    user_id        ISBN  rating  \
# 0   277427  002542730X      10
# 1   277427  003008685X       8
# 2   277427  006092988X       0
# 3   277427  006440188X       0
# 4   277427  014029628X       0
#
#                                                title                   author  \
# 0  Politically Correct Bedtime Stories: Modern Ta...        James Finn Garner
# 1                                           Pioneers    James Fenimore Cooper
# 2                           A Tree Grows in Brooklyn              Betty Smith
# 3                                  The Secret Garden  Frances Hodgson Burnett
# 4                              Girl in Hyacinth Blue           Susan Vreeland
#
#    year                  publisher  \
# 0  1994  John Wiley &amp; Sons Inc
# 1  1974           Thomson Learning
# 2  1998                  Perennial
# 3  1998               HarperTrophy
# 4  2000              Penguin Books
#
#                                            image_url  num_of_rating
# 0  http://images.amazon.com/images/P/002542730X.0...             82
# 1  http://images.amazon.com/images/P/003008685X.0...              1
# 2  http://images.amazon.com/images/P/006092988X.0...             31
# 3  http://images.amazon.com/images/P/006440188X.0...             29
# 4  http://images.amazon.com/images/P/014029628X.0...             91

# %%
# Lets take those books which got at least 50 rating of user

final_rating = final_rating[final_rating['num_of_rating'] >= 50]

# %%
final_rating.head()
# Out:
#     user_id        ISBN  rating  \
# 0    277427  002542730X      10
# 4    277427  014029628X       0
# 6    277427  014100018X       0
# 8    277427  031298328X       0
# 32   277427  080410753X       0
#
#                                                 title             author  \
# 0   Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner
# 4                               Girl in Hyacinth Blue     Susan Vreeland
# 6                                            Chocolat      Joanne Harris
# 8           Full Tilt (Janet Evanovich's Full Series)    Janet Evanovich
# 32                             The Kitchen God's Wife            Amy Tan
#
#     year                  publisher  \
# 0   1994  John Wiley &amp; Sons Inc
# 4   2000              Penguin Books
# 6   2000              Penguin Books
# 8   2003    St. Martin's Paperbacks
# 32  1992                  Ivy Books
#
#                                             image_url  num_of_rating
# 0   http://images.amazon.com/images/P/002542730X.0...             82
# 4   http://images.amazon.com/images/P/014029628X.0...             91
# 6   http://images.amazon.com/images/P/014100018X.0...             59
# 8   http://images.amazon.com/images/P/031298328X.0...             79
# 32  http://images.amazon.com/images/P/080410753X.0...            101

# %%
# lets drop the duplicates
final_rating.drop_duplicates(['user_id','title'],inplace=True)

# %%
final_rating.isnull().sum()
# Out:
# user_id          0
# ISBN             0
# rating           0
# title            0
# author           0
# year             0
# publisher        0
# image_url        0
# num_of_rating    0
# dtype: int64

# %%
# Lets create a pivot table
book_pivot = final_rating.pivot_table(columns='user_id', index='title', values= 'rating')
book_pivot
# Out:
# user_id                                             254     2276    2766    \
# title
# A Child Called \It\": One Child's Courage to Su...     NaN     NaN     NaN
# A Fine Balance                                         NaN     NaN     NaN
# A Painted House                                        NaN     NaN     NaN
# A Patchwork Planet                                     NaN     NaN     NaN
# A Widow for One Year                                   NaN     NaN     NaN
# ...                                                    ...     ...     ...
# The Tale of the Body Thief (Vampire Chronicles ...     NaN     0.0     NaN
# Turtle Moon                                            NaN     NaN     NaN
# Welcome to the World, Baby Girl!                       NaN     NaN     NaN
# What Looks Like Crazy On An Ordinary Day               NaN     NaN     NaN
# What to Expect When You're Expecting (Revised E...     NaN     NaN     NaN
#
# user_id                                             2977    3363    4017    \
# title
# A Child Called \It\": One Child's Courage to Su...     NaN     NaN     NaN
# A Fine Balance                                         NaN     NaN     NaN
# A Painted House                                        NaN     NaN     NaN
# A Patchwork Planet                                     NaN     NaN     NaN
# A Widow for One Year                                   NaN     NaN     NaN
# ...                                                    ...     ...     ...
# The Tale of the Body Thief (Vampire Chronicles ...     NaN     NaN     NaN
# Turtle Moon                                            NaN     NaN     NaN
# Welcome to the World, Baby Girl!                       NaN     0.0     NaN
# What Looks Like Crazy On An Ordinary Day               NaN     NaN     NaN
# What to Expect When You're Expecting (Revised E...     NaN     0.0     NaN
#
# user_id                                             6242    6251    6323    \
# title
# A Child Called \It\": One Child's Courage to Su...     NaN     NaN     NaN
# A Fine Balance                                         NaN     NaN     NaN
# A Painted House                                        NaN     0.0     NaN
# A Patchwork Planet                                     NaN     NaN     NaN
# A Widow for One Year                                   NaN     NaN     NaN
# ...                                                    ...     ...     ...
# The Tale of the Body Thief (Vampire Chronicles ...     NaN     0.0     0.0
# Turtle Moon                                            NaN     NaN     NaN
# Welcome to the World, Baby Girl!                       NaN     NaN     NaN
# What Looks Like Crazy On An Ordinary Day               NaN     NaN     NaN
# What to Expect When You're Expecting (Revised E...     NaN     NaN     NaN
#
# user_id                                             6543    ...  274004  \
# title                                                       ...
# A Child Called \It\": One Child's Courage to Su...     NaN  ...     NaN
# A Fine Balance                                         NaN  ...     NaN
# A Painted House                                        NaN  ...     0.0
# A Patchwork Planet                                     NaN  ...     NaN
# A Widow for One Year                                   NaN  ...     NaN
# ...                                                    ...  ...     ...
# The Tale of the Body Thief (Vampire Chronicles ...     NaN  ...     NaN
# Turtle Moon                                            NaN  ...     NaN
# Welcome to the World, Baby Girl!                       NaN  ...     NaN
# What Looks Like Crazy On An Ordinary Day               NaN  ...     NaN
# What to Expect When You're Expecting (Revised E...     0.0  ...     NaN
#
# user_id                                             274061  274301  274308  \
# title
# A Child Called \It\": One Child's Courage to Su...     NaN     NaN     NaN
# A Fine Balance                                         NaN     NaN     NaN
# A Painted House                                        NaN     NaN     0.0
# A Patchwork Planet                                     NaN     NaN     NaN
# A Widow for One Year                                   NaN     NaN     NaN
# ...                                                    ...     ...     ...
# The Tale of the Body Thief (Vampire Chronicles ...     NaN     NaN     NaN
# Turtle Moon                                            NaN     NaN     NaN
# Welcome to the World, Baby Girl!                       NaN     NaN     NaN
# What Looks Like Crazy On An Ordinary Day               NaN     NaN     NaN
# What to Expect When You're Expecting (Revised E...     NaN     NaN     NaN
#
# user_id                                             274808  275970  277427  \
# title
# A Child Called \It\": One Child's Courage to Su...     NaN     NaN     NaN
# A Fine Balance                                         NaN     0.0     NaN
# A Painted House                                        0.0     NaN     NaN
# A Patchwork Planet                                     NaN     NaN     0.0
# A Widow for One Year                                   NaN     NaN     NaN
# ...                                                    ...     ...     ...
# The Tale of the Body Thief (Vampire Chronicles ...     NaN     NaN     NaN
# Turtle Moon                                            0.0     NaN     NaN
# Welcome to the World, Baby Girl!                       NaN     NaN     NaN
# What Looks Like Crazy On An Ordinary Day               NaN     NaN     NaN
# What to Expect When You're Expecting (Revised E...     NaN     NaN     NaN
#
# user_id                                             277478  277639  278418
# title
# A Child Called \It\": One Child's Courage to Su...     NaN     NaN     NaN
# A Fine Balance                                         NaN     NaN     NaN
# A Painted House                                        NaN     NaN     0.0
# A Patchwork Planet                                     NaN     NaN     NaN
# A Widow for One Year                                   NaN     NaN     NaN
# ...                                                    ...     ...     ...
# The Tale of the Body Thief (Vampire Chronicles ...     NaN     NaN     0.0
# Turtle Moon                                            NaN     NaN     0.0
# Welcome to the World, Baby Girl!                       NaN     NaN     NaN
# What Looks Like Crazy On An Ordinary Day               NaN     NaN     NaN
# What to Expect When You're Expecting (Revised E...     NaN     NaN     NaN
#
# [70 rows x 810 columns]

# %%
book_pivot.shape
# Out:
# (70, 810)

# %%
book_pivot.fillna(0, inplace=True)
book_pivot
# Out:
# user_id                                             254     2276    2766    \
# title
# A Child Called \It\": One Child's Courage to Su...     0.0     0.0     0.0
# A Fine Balance                                         0.0     0.0     0.0
# A Painted House                                        0.0     0.0     0.0
# A Patchwork Planet                                     0.0     0.0     0.0
# A Widow for One Year                                   0.0     0.0     0.0
# ...                                                    ...     ...     ...
# The Tale of the Body Thief (Vampire Chronicles ...     0.0     0.0     0.0
# Turtle Moon                                            0.0     0.0     0.0
# Welcome to the World, Baby Girl!                       0.0     0.0     0.0
# What Looks Like Crazy On An Ordinary Day               0.0     0.0     0.0
# What to Expect When You're Expecting (Revised E...     0.0     0.0     0.0
#
# user_id                                             2977    3363    4017    \
# title
# A Child Called \It\": One Child's Courage to Su...     0.0     0.0     0.0
# A Fine Balance                                         0.0     0.0     0.0
# A Painted House                                        0.0     0.0     0.0
# A Patchwork Planet                                     0.0     0.0     0.0
# A Widow for One Year                                   0.0     0.0     0.0
# ...                                                    ...     ...     ...
# The Tale of the Body Thief (Vampire Chronicles ...     0.0     0.0     0.0
# Turtle Moon                                            0.0     0.0     0.0
# Welcome to the World, Baby Girl!                       0.0     0.0     0.0
# What Looks Like Crazy On An Ordinary Day               0.0     0.0     0.0
# What to Expect When You're Expecting (Revised E...     0.0     0.0     0.0
#
# user_id                                             6242    6251    6323    \
# title
# A Child Called \It\": One Child's Courage to Su...     0.0     0.0     0.0
# A Fine Balance                                         0.0     0.0     0.0
# A Painted House                                        0.0     0.0     0.0
# A Patchwork Planet                                     0.0     0.0     0.0
# A Widow for One Year                                   0.0     0.0     0.0
# ...                                                    ...     ...     ...
# The Tale of the Body Thief (Vampire Chronicles ...     0.0     0.0     0.0
# Turtle Moon                                            0.0     0.0     0.0
# Welcome to the World, Baby Girl!                       0.0     0.0     0.0
# What Looks Like Crazy On An Ordinary Day               0.0     0.0     0.0
# What to Expect When You're Expecting (Revised E...     0.0     0.0     0.0
#
# user_id                                             6543    ...  274004  \
# title                                                       ...
# A Child Called \It\": One Child's Courage to Su...     0.0  ...     0.0
# A Fine Balance                                         0.0  ...     0.0
# A Painted House                                        0.0  ...     0.0
# A Patchwork Planet                                     0.0  ...     0.0
# A Widow for One Year                                   0.0  ...     0.0
# ...                                                    ...  ...     ...
# The Tale of the Body Thief (Vampire Chronicles ...     0.0  ...     0.0
# Turtle Moon                                            0.0  ...     0.0
# Welcome to the World, Baby Girl!                       0.0  ...     0.0
# What Looks Like Crazy On An Ordinary Day               0.0  ...     0.0
# What to Expect When You're Expecting (Revised E...     0.0  ...     0.0
#
# user_id                                             274061  274301  274308  \
# title
# A Child Called \It\": One Child's Courage to Su...     0.0     0.0     0.0
# A Fine Balance                                         0.0     0.0     0.0
# A Painted House                                        0.0     0.0     0.0
# A Patchwork Planet                                     0.0     0.0     0.0
# A Widow for One Year                                   0.0     0.0     0.0
# ...                                                    ...     ...     ...
# The Tale of the Body Thief (Vampire Chronicles ...     0.0     0.0     0.0
# Turtle Moon                                            0.0     0.0     0.0
# Welcome to the World, Baby Girl!                       0.0     0.0     0.0
# What Looks Like Crazy On An Ordinary Day               0.0     0.0     0.0
# What to Expect When You're Expecting (Revised E...     0.0     0.0     0.0
#
# user_id                                             274808  275970  277427  \
# title
# A Child Called \It\": One Child's Courage to Su...     0.0     0.0     0.0
# A Fine Balance                                         0.0     0.0     0.0
# A Painted House                                        0.0     0.0     0.0
# A Patchwork Planet                                     0.0     0.0     0.0
# A Widow for One Year                                   0.0     0.0     0.0
# ...                                                    ...     ...     ...
# The Tale of the Body Thief (Vampire Chronicles ...     0.0     0.0     0.0
# Turtle Moon                                            0.0     0.0     0.0
# Welcome to the World, Baby Girl!                       0.0     0.0     0.0
# What Looks Like Crazy On An Ordinary Day               0.0     0.0     0.0
# What to Expect When You're Expecting (Revised E...     0.0     0.0     0.0
#
# user_id                                             277478  277639  278418
# title
# A Child Called \It\": One Child's Courage to Su...     0.0     0.0     0.0
# A Fine Balance                                         0.0     0.0     0.0
# A Painted House                                        0.0     0.0     0.0
# A Patchwork Planet                                     0.0     0.0     0.0
# A Widow for One Year                                   0.0     0.0     0.0
# ...                                                    ...     ...     ...
# The Tale of the Body Thief (Vampire Chronicles ...     0.0     0.0     0.0
# Turtle Moon                                            0.0     0.0     0.0
# Welcome to the World, Baby Girl!                       0.0     0.0     0.0
# What Looks Like Crazy On An Ordinary Day               0.0     0.0     0.0
# What to Expect When You're Expecting (Revised E...     0.0     0.0     0.0
#
# [70 rows x 810 columns]

# %%
book_pivot.shape
# Out:
# (70, 810)

# %%
from scipy.sparse import csr_matrix

# %%
book_sparse = csr_matrix(book_pivot.values)
book_sparse
# Out:
# <70x810 sparse matrix of type '<class 'numpy.float64'>'
# 	with 1481 stored elements in Compressed Sparse Row format>

# %%
type(book_sparse)
# Out:
# scipy.sparse._csr.csr_matrix

# %%
from sklearn.neighbors import NearestNeighbors
model = NearestNeighbors(metric='cosine', algorithm= 'brute')

# %%
model.fit(book_sparse)
# Out:
# NearestNeighbors(algorithm='brute', metric='cosine')

# %%
book_pivot.iloc[69,:]  # Getting the distance and suggestion for the book from user

distance, suggestion = model.kneighbors(book_pivot.iloc[69,:].values.reshape(1,-1), n_neighbors=6 )

# %%
distance
# Out:
# array([[2.22044605e-16, 8.14266984e-01, 8.21358818e-01, 8.32360373e-01,
#         8.63798408e-01, 8.69242940e-01]])

# %%
suggestion
# Out:
# array([[69, 16, 15, 42, 58, 35]], dtype=int64)

# %%
for i in range(len(suggestion)):
    print(book_pivot.index[suggestion[i]])
# Out:
# Index(['What to Expect When You're Expecting (Revised Edition)',
#        'Chicken Soup for the Woman's Soul (Chicken Soup for the Soul Series (Paper))',
#        'Chicken Soup for the Soul (Chicken Soup for the Soul)', 'Rising Tides',
#        'The Lost Boy: A Foster Child's Search for the Love of a Family',
#        'Men Are from Mars, Women Are from Venus: A Practical Guide for Improving Communication and Getting What You Want in Your Relationships'],
#       dtype='object', name='title')

# %%
#keeping books name
book_title = book_pivot.index

# %%
book_title
# Out:
# Index(['A Child Called \It\": One Child's Courage to Survive"',
#        'A Fine Balance', 'A Painted House', 'A Patchwork Planet',
#        'A Widow for One Year', 'All I Really Need to Know',
#        'Angela's Ashes: A Memoir',
#        'Anne of Green Gables (Anne of Green Gables Novels (Paperback))',
#        'At Home in Mitford (The Mitford Years)', 'Atonement : A Novel',
#        'Bag of Bones', 'Breath, Eyes, Memory', 'Breathing Lessons',
#        'Bridget Jones's Diary', 'Call of the Wild',
#        'Chicken Soup for the Soul (Chicken Soup for the Soul)',
#        'Chicken Soup for the Woman's Soul (Chicken Soup for the Soul Series (Paper))',
#        'Chocolat', 'Cry Wolf', 'Degree of Guilt', 'Dreamcatcher',
#        'Face the Fire (Three Sisters Island Trilogy)', 'Fingersmith',
#        'Flesh and Blood',
#        'Forever... : A Novel of Good and Evil, Love and Hope',
#        'Full Tilt (Janet Evanovich's Full Series)', 'Girl in Hyacinth Blue',
#        'Harry Potter and the Order of the Phoenix (Book 5)',
#        'Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback))',
#        'Hideaway', 'High Fidelity', 'Hornet's Nest', 'How to Be Good',
#        'Key of Light (Key Trilogy (Paperback))',
#        'Like Water for Chocolate : A Novel in Monthly Installments with Recipes, Romances, and Home Remedies',
#        'Men Are from Mars, Women Are from Venus: A Practical Guide for Improving Communication and Getting What You Want in Your Relationships',
#        'Morality for Beautiful Girls (No.1 Ladies Detective Agency)',
#        'Night Sins', 'One True Thing',
#        'Politically Correct Bedtime Stories: Modern Tales for Our Life and Times',
#        'Purity in Death', 'Red Storm Rising', 'Rising Tides',
#        'STONES FROM THE RIVER', 'Snow Falling on Cedars',
#        'Tears of the Giraffe (No.1 Ladies Detective Agency)',
#        'That Camden Summer', 'The Bridges of Madison County',
#        'The Celestine Prophecy (Celestine Prophecy)',
#        'The Clinic (Alex Delaware Novels (Paperback))',
#        'The Color of Water: A Black Man's Tribute to His White Mother',
#        'The Crimson Petal and the White', 'The Devil Wears Prada : A Novel',
#        'The Firm', 'The Girls' Guide to Hunting and Fishing',
#        'The Hundred Secret Senses', 'The Kiss', 'The Kitchen God's Wife',
#        'The Lost Boy: A Foster Child's Search for the Love of a Family',
#        'The Lost World',
#        'The No. 1 Ladies' Detective Agency (Today Show Book Club #8)',
#        'The Perfect Storm : A True Story of Men Against the Sea',
#        'The Rainmaker', 'The Reef', 'The Stone Diaries',
#        'The Tale of the Body Thief (Vampire Chronicles (Paperback))',
#        'Turtle Moon', 'Welcome to the World, Baby Girl!',
#        'What Looks Like Crazy On An Ordinary Day',
#        'What to Expect When You're Expecting (Revised Edition)'],
#       dtype='object', name='title')

# %%
book_title[4]
# Out:
# 'A Widow for One Year'

# %%
final_rating.head()
# Out:
#     user_id        ISBN  rating  \
# 0    277427  002542730X      10
# 4    277427  014029628X       0
# 6    277427  014100018X       0
# 8    277427  031298328X       0
# 32   277427  080410753X       0
#
#                                                 title             author  \
# 0   Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner
# 4                               Girl in Hyacinth Blue     Susan Vreeland
# 6                                            Chocolat      Joanne Harris
# 8           Full Tilt (Janet Evanovich's Full Series)    Janet Evanovich
# 32                             The Kitchen God's Wife            Amy Tan
#
#     year                  publisher  \
# 0   1994  John Wiley &amp; Sons Inc
# 4   2000              Penguin Books
# 6   2000              Penguin Books
# 8   2003    St. Martin's Paperbacks
# 32  1992                  Ivy Books
#
#                                             image_url  num_of_rating
# 0   http://images.amazon.com/images/P/002542730X.0...             82
# 4   http://images.amazon.com/images/P/014029628X.0...             91
# 6   http://images.amazon.com/images/P/014100018X.0...             59
# 8   http://images.amazon.com/images/P/031298328X.0...             79
# 32  http://images.amazon.com/images/P/080410753X.0...            101

# %%
book_title = []
for book_id in suggestion:
    book_title.append(book_pivot.index[book_id])

# %%
book_title
# Out:
# [Index(['What to Expect When You're Expecting (Revised Edition)',
#         'Chicken Soup for the Woman's Soul (Chicken Soup for the Soul Series (Paper))',
#         'Chicken Soup for the Soul (Chicken Soup for the Soul)', 'Rising Tides',
#         'The Lost Boy: A Foster Child's Search for the Love of a Family',
#         'Men Are from Mars, Women Are from Venus: A Practical Guide for Improving Communication and Getting What You Want in Your Relationships'],
#        dtype='object', name='title')]

# %%
ids_index = []
for name in book_title[0]: 
    ids = np.where(final_rating['title'] == name)[0][0]
    ids_index.append(ids)

# %%
ids_index
# Out:
# [48, 50, 49, 32, 150, 10]

# %%
for idx in ids_index:
    url = final_rating.iloc[idx]['image_url']
    print(url)
# Out:
# http://images.amazon.com/images/P/089480829X.01.LZZZZZZZ.jpg
# http://images.amazon.com/images/P/1558744150.01.LZZZZZZZ.jpg
# http://images.amazon.com/images/P/155874262X.01.LZZZZZZZ.jpg
# http://images.amazon.com/images/P/051512317X.01.LZZZZZZZ.jpg
# http://images.amazon.com/images/P/1558745157.01.LZZZZZZZ.jpg
# http://images.amazon.com/images/P/006016848X.01.LZZZZZZZ.jpg

# %%
import pickle
pickle.dump(model,open('artifacts/model.pkl','wb'))
pickle.dump(book_title,open('artifacts/book_names.pkl','wb'))
pickle.dump(final_rating,open('artifacts/final_rating.pkl','wb'))
pickle.dump(book_pivot,open('artifacts/book_pivot.pkl','wb'))

# %% [markdown]
# Testing Model

# %%
def recommend_book(book_title):
    book_id = np.where(book_pivot.index == book_title)[0][0]
    distance, suggestion = model.kneighbors(book_pivot.iloc[book_id,:].values.reshape(1,-1), n_neighbors=6 )
    
    for i in range(len(suggestion)):
            books = book_pivot.index[suggestion[i]]
            for j in books:
                if j == book_title:
                    print(f"You searched '{book_title}'\n")
                    print("The suggestion books are: \n")
                else:
                    print(j)

# %%
book_title = "Flesh and Blood"
recommend_book(book_title)
# Out:
# You searched 'Flesh and Blood'
#
# The suggestion books are:
#
# Dreamcatcher
# The Clinic (Alex Delaware Novels (Paperback))
# The Kiss
# Call of the Wild
# Bag of Bones
